# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[2,4,16,8])

# %%
#using labels
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[2,4,16,8])
plt.ylabel("values")
plt.xlabel("data")
# Out:
# Text(0.5, 0, 'data')

# %%
#to plot graph in different ways
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[2,4,16,8],'bo')
plt.ylabel("values")
plt.xlabel("data")
# Out:
# Text(0.5, 0, 'data')

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[2,4,16,8],'g^')
plt.ylabel("values")
plt.xlabel("data")
# Out:
# Text(0.5, 0, 'data')

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[2,4,16,8],'r--')
plt.ylabel("values")
plt.xlabel("data")
# Out:
# Text(0.5, 0, 'data')

# %%
import matplotlib.pyplot as plt
import statistics
estimates = [300,400,980,564,789,300,200,678,500,200,250,800,100,900,230,300,450,600,290,320,760,1600,280,380,962,300,346,234,765,123,179,241]
estimates.sort()
tv=int(0.1*(len(estimates)))
estimates=estimates[tv:len(estimates)-tv]
y=[]
for i in range(len(estimates)):
  y.append(5)
plt.plot(estimates,y,'r--')
plt.plot([statistics.mean(estimates)],[5],'ro')
plt.plot([statistics.median(estimates)],[5],'bs')
plt.plot([375],[5],'g^')
